# %%
import os
import pandas as pd 
import numpy as np 
import seaborn as sns
import sys
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Step-1 Data Collection

# %%
ds_train = pd.read_csv("Google_Stock_Price_Train.csv")
ds_train
# Out:
#             Date    Open    High     Low   Close      Volume
# 0       1/3/2012  325.25  332.83  324.97  663.59   7,380,500
# 1       1/4/2012  331.27  333.87  329.08  666.45   5,749,400
# 2       1/5/2012  329.83  330.75  326.89  657.21   6,590,300
# 3       1/6/2012  328.34  328.77  323.68  648.24   5,405,900
# 4       1/9/2012  322.04  322.29  309.46  620.76  11,688,800
# ...          ...     ...     ...     ...     ...         ...
# 1253  12/23/2016  790.90  792.74  787.28  789.91     623,400
# 1254  12/27/2016  790.68  797.86  787.66  791.55     789,100
# 1255  12/28/2016  793.70  794.23  783.20  785.05   1,153,800
# 1256  12/29/2016  783.33  785.93  778.92  782.79     744,300
# 1257  12/30/2016  782.75  782.78  770.41  771.82   1,770,000
#
# [1258 rows x 6 columns]

# %%
ds_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1258 entries, 0 to 1257
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    1258 non-null   object
#  1   Open    1258 non-null   float64
#  2   High    1258 non-null   float64
#  3   Low     1258 non-null   float64
#  4   Close   1258 non-null   object
#  5   Volume  1258 non-null   object
# dtypes: float64(3), object(3)
# memory usage: 59.1+ KB

# %%
ds_train.head()
# Out:
#        Date    Open    High     Low   Close      Volume
# 0  1/3/2012  325.25  332.83  324.97  663.59   7,380,500
# 1  1/4/2012  331.27  333.87  329.08  666.45   5,749,400
# 2  1/5/2012  329.83  330.75  326.89  657.21   6,590,300
# 3  1/6/2012  328.34  328.77  323.68  648.24   5,405,900
# 4  1/9/2012  322.04  322.29  309.46  620.76  11,688,800

# %%
training_set = ds_train.iloc[:,1:2]
training_set
# Out:
#         Open
# 0     325.25
# 1     331.27
# 2     329.83
# 3     328.34
# 4     322.04
# ...      ...
# 1253  790.90
# 1254  790.68
# 1255  793.70
# 1256  783.33
# 1257  782.75
#
# [1258 rows x 1 columns]

# %%
training_set.shape
# Out:
# (1258, 1)

# %% [markdown]
# ## Step-2 Data Preprocessing

# %%
from sklearn.preprocessing import MinMaxScaler
MMscaler = MinMaxScaler(feature_range = (0,1))
scaled_train_set = MMscaler.fit_transform(training_set)
scaled_train_set
# Out:
# array([[0.08581368],
#        [0.09701243],
#        [0.09433366],
#        ...,
#        [0.95725128],
#        [0.93796041],
#        [0.93688146]])

# %%
X_train = []
y_train = []
for i in range(30,1258):
    X_train.append(scaled_train_set[i-30:i,0])
    y_train.append(scaled_train_set[i,0])
X_train = np.array(X_train)
y_train = np.array(y_train)

# %%
print(X_train)
X_train.shape
# Out:
# [[0.08581368 0.09701243 0.09433366 ... 0.0440695  0.04648783 0.04745517]
#  [0.09701243 0.09433366 0.09156187 ... 0.04648783 0.04745517 0.04873875]
#  [0.09433366 0.09156187 0.07984225 ... 0.04745517 0.04873875 0.03936305]
#  ...
#  [0.88637547 0.87032145 0.88563137 ... 0.95475854 0.95204256 0.95163331]
#  [0.87032145 0.88563137 0.90743359 ... 0.95204256 0.95163331 0.95725128]
#  [0.88563137 0.90743359 0.91571173 ... 0.95163331 0.95725128 0.93796041]]
# (1228, 30)

# %%
y_train
# Out:
# array([0.04873875, 0.03936305, 0.04137213, ..., 0.95725128, 0.93796041,
#        0.93688146])

# %%
X_train =  np.reshape(X_train,(X_train.shape[0],X_train.shape[1],1))
X_train.shape
# Out:
# (1228, 30, 1)

# %%
X_train
# Out:
# array([[[0.08581368],
#         [0.09701243],
#         [0.09433366],
#         ...,
#         [0.0440695 ],
#         [0.04648783],
#         [0.04745517]],
#
#        [[0.09701243],
#         [0.09433366],
#         [0.09156187],
#         ...,
#         [0.04648783],
#         [0.04745517],
#         [0.04873875]],
#
#        [[0.09433366],
#         [0.09156187],
#         [0.07984225],
#         ...,
#         [0.04745517],
#         [0.04873875],
#         [0.03936305]],
#
#        ...,
#
#        [[0.88637547],
#         [0.87032145],
#         [0.88563137],
#         ...,
#         [0.95475854],
#         [0.95204256],
#         [0.95163331]],
#
#        [[0.87032145],
#         [0.88563137],
#         [0.90743359],
#         ...,
#         [0.95204256],
#         [0.95163331],
#         [0.95725128]],
#
#        [[0.88563137],
#         [0.90743359],
#         [0.91571173],
#         ...,
#         [0.95163331],
#         [0.95725128],
#         [0.93796041]]])

# %% [markdown]
# ## step-3 Apllying LSTM method

# %%
# !pip install keras
# !pip install tensorflow
import tensorflow as tf
from tensorflow.keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
from keras.layers import Dropout
# Out:
# Requirement already satisfied: keras in c:\users\chatt\anaconda3\lib\site-packages (2.14.0)
# Requirement already satisfied: tensorflow in c:\users\chatt\anaconda3\lib\site-packages (2.14.0)
# Requirement already satisfied: tensorflow-intel==2.14.0 in c:\users\chatt\anaconda3\lib\site-packages (from tensorflow) (2.14.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\chatt\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (2.0.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\chatt\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in c:\users\chatt\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (23.5.26)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\chatt\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\chatt\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\chatt\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (3.9.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\chatt\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (16.0.6)
# Requirement already satisfied: ml-dtypes==0.2.0 in c:\users\chatt\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (0.2.0)
# Requirement already satisfied: numpy>=1.23.5 in c:\users\chatt\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (1.24.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\chatt\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (3.3.0)
# Requirement already satisfied: packaging in c:\users\chatt\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (23.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\chatt\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (4.24.4)
# Requirement already satisfied: setuptools in c:\users\chatt\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (68.0.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\chatt\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\chatt\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (2.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\chatt\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (4.7.1)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in c:\users\chatt\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\chatt\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (0.31.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\chatt\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (1.59.0)
# Requirement already satisfied: tensorboard<2.15,>=2.14 in c:\users\chatt\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (2.14.1)
# Requirement already satisfied: tensorflow-estimator<2.15,>=2.14.0 in c:\users\chatt\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (2.14.0)
# Requirement already satisfied: keras<2.15,>=2.14.0 in c:\users\chatt\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (2.14.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\chatt\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.14.0->tensorflow) (0.38.4)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\chatt\anaconda3\lib\site-packages (from tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (2.23.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in c:\users\chatt\anaconda3\lib\site-packages (from tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\chatt\anaconda3\lib\site-packages (from tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (3.4.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\chatt\anaconda3\lib\site-packages (from tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\chatt\anaconda3\lib\site-packages (from tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (0.7.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\chatt\anaconda3\lib\site-packages (from tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (2.2.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\chatt\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\chatt\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\chatt\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\chatt\anaconda3\lib\site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\chatt\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\chatt\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\chatt\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\chatt\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\chatt\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (2.1.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\chatt\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\chatt\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (3.2.2)

# %%
regressor = Sequential()
regressor.add(LSTM(units = 50, return_sequences= True, input_shape = (X_train.shape[1],1)))
regressor.add(Dropout(0.2))
regressor.add(LSTM(units = 50, return_sequences= True))
regressor.add(Dropout(0.2))
regressor.add(LSTM(units = 50, return_sequences= True))
regressor.add(Dropout(0.2))
regressor.add(LSTM(units = 50))
regressor.add(Dropout(0.2))

regressor.add(Dense(units=1))

# %%
regressor.compile(optimizer = 'adam', loss = 'mean_squared_error')
regressor.fit(X_train,y_train, epochs=100, batch_size=64)
# Out:
# Epoch 1/100
# 20/20 [==============================] - 11s 89ms/step - loss: 0.0761
# Epoch 2/100
# 20/20 [==============================] - 2s 84ms/step - loss: 0.0107
# Epoch 3/100
# 20/20 [==============================] - 2s 86ms/step - loss: 0.0058
# Epoch 4/100
# 20/20 [==============================] - 2s 84ms/step - loss: 0.0056
# Epoch 5/100
# 20/20 [==============================] - 2s 86ms/step - loss: 0.0049
# Epoch 6/100
# 20/20 [==============================] - 2s 84ms/step - loss: 0.0049
# Epoch 7/100
# 20/20 [==============================] - 2s 82ms/step - loss: 0.0052
# Epoch 8/100
# 20/20 [==============================] - 2s 81ms/step - loss: 0.0048
# Epoch 9/100
# 20/20 [==============================] - 2s 83ms/step - loss: 0.0050
# Epoch 10/100
# 20/20 [==============================] - 2s 82ms/step - loss: 0.0044
# Epoch 11/100
# 20/20 [==============================] - 2s 91ms/step - loss: 0.0043
# Epoch 12/100
# 20/20 [==============================] - 2s 85ms/step - loss: 0.0048
# Epoch 13/100
# 20/20 [==============================] - 2s 87ms/step - loss: 0.0044
# Epoch 14/100
# 20/20 [==============================] - 2s 87ms/step - loss: 0.0043
# Epoch 15/100
# 20/20 [==============================] - 2s 93ms/step - loss: 0.0038
# Epoch 16/100
# 20/20 [==============================] - 2s 93ms/step - loss: 0.0045
# Epoch 17/100
# 20/20 [==============================] - 2s 92ms/step - loss: 0.0038
# Epoch 18/100
# 20/20 [==============================] - 2s 89ms/step - loss: 0.0040
# Epoch 19/100
# 20/20 [==============================] - 2s 96ms/step - loss: 0.0041
# Epoch 20/100
# 20/20 [==============================] - 2s 87ms/step - loss: 0.0040
# Epoch 21/100
# 20/20 [==============================] - 2s 90ms/step - loss: 0.0035
# Epoch 22/100
# 20/20 [==============================] - 2s 103ms/step - loss: 0.0038
# Epoch 23/100
# 20/20 [==============================] - 2s 88ms/step - loss: 0.0038
# Epoch 24/100
# 20/20 [==============================] - 2s 87ms/step - loss: 0.0038
# Epoch 25/100
# 20/20 [==============================] - 2s 87ms/step - loss: 0.0037
# Epoch 26/100
# 20/20 [==============================] - 2s 86ms/step - loss: 0.0036
# Epoch 27/100
# 20/20 [==============================] - 2s 81ms/step - loss: 0.0038
# Epoch 28/100
# 20/20 [==============================] - 2s 83ms/step - loss: 0.0040
# Epoch 29/100
# 20/20 [==============================] - 2s 101ms/step - loss: 0.0037
# Epoch 30/100
# 20/20 [==============================] - 2s 92ms/step - loss: 0.0034
# Epoch 31/100
# 20/20 [==============================] - 2s 90ms/step - loss: 0.0036
# Epoch 32/100
# 20/20 [==============================] - 2s 97ms/step - loss: 0.0041
# Epoch 33/100
# 20/20 [==============================] - 2s 91ms/step - loss: 0.0040
# Epoch 34/100
# 20/20 [==============================] - 2s 92ms/step - loss: 0.0032
# Epoch 35/100
# 20/20 [==============================] - 2s 83ms/step - loss: 0.0039
# Epoch 36/100
# 20/20 [==============================] - 2s 81ms/step - loss: 0.0035
# Epoch 37/100
# 20/20 [==============================] - 2s 84ms/step - loss: 0.0031
# Epoch 38/100
# 20/20 [==============================] - 2s 85ms/step - loss: 0.0033
# Epoch 39/100
# 20/20 [==============================] - 2s 84ms/step - loss: 0.0032
# Epoch 40/100
# 20/20 [==============================] - 2s 85ms/step - loss: 0.0032
# Epoch 41/100
# 20/20 [==============================] - 2s 85ms/step - loss: 0.0032
# Epoch 42/100
# 20/20 [==============================] - 2s 84ms/step - loss: 0.0031
# Epoch 43/100
# 20/20 [==============================] - 2s 83ms/step - loss: 0.0033
# Epoch 44/100
# 20/20 [==============================] - 2s 80ms/step - loss: 0.0032
# Epoch 45/100
# 20/20 [==============================] - 2s 80ms/step - loss: 0.0032
# Epoch 46/100
# 20/20 [==============================] - 2s 80ms/step - loss: 0.0031
# Epoch 47/100
# 20/20 [==============================] - 2s 87ms/step - loss: 0.0030
# Epoch 48/100
# 20/20 [==============================] - 2s 86ms/step - loss: 0.0037
# Epoch 49/100
# 20/20 [==============================] - 2s 87ms/step - loss: 0.0030
# Epoch 50/100
# 20/20 [==============================] - 2s 86ms/step - loss: 0.0032
# Epoch 51/100
# 20/20 [==============================] - 2s 85ms/step - loss: 0.0030
# Epoch 52/100
# 20/20 [==============================] - 2s 87ms/step - loss: 0.0029
# Epoch 53/100
# 20/20 [==============================] - 2s 82ms/step - loss: 0.0030
# Epoch 54/100
# 20/20 [==============================] - 2s 87ms/step - loss: 0.0032
# Epoch 55/100
# 20/20 [==============================] - 2s 90ms/step - loss: 0.0030
# Epoch 56/100
# 20/20 [==============================] - 2s 87ms/step - loss: 0.0029
# Epoch 57/100
# 20/20 [==============================] - 2s 90ms/step - loss: 0.0033
# Epoch 58/100
# 20/20 [==============================] - 2s 99ms/step - loss: 0.0033
# Epoch 59/100
# 20/20 [==============================] - 2s 110ms/step - loss: 0.0031
# Epoch 60/100
# 20/20 [==============================] - 2s 94ms/step - loss: 0.0029
# Epoch 61/100
# 20/20 [==============================] - 2s 93ms/step - loss: 0.0030
# Epoch 62/100
# 20/20 [==============================] - 2s 88ms/step - loss: 0.0028
# Epoch 63/100
# 20/20 [==============================] - 2s 82ms/step - loss: 0.0028
# Epoch 64/100
# 20/20 [==============================] - 6s 291ms/step - loss: 0.0026
# Epoch 65/100
# 20/20 [==============================] - 4s 177ms/step - loss: 0.0029
# Epoch 66/100
# 20/20 [==============================] - 3s 139ms/step - loss: 0.0026
# Epoch 67/100
# 20/20 [==============================] - 2s 123ms/step - loss: 0.0028
# Epoch 68/100
# 20/20 [==============================] - 2s 120ms/step - loss: 0.0027
# Epoch 69/100
# 20/20 [==============================] - 3s 129ms/step - loss: 0.0026
# Epoch 70/100
# 20/20 [==============================] - 3s 125ms/step - loss: 0.0023
# Epoch 71/100
# 20/20 [==============================] - 2s 117ms/step - loss: 0.0028
# Epoch 72/100
# 20/20 [==============================] - 2s 109ms/step - loss: 0.0024
# Epoch 73/100
# 20/20 [==============================] - 2s 111ms/step - loss: 0.0028
# Epoch 74/100
# 20/20 [==============================] - 2s 111ms/step - loss: 0.0026
# Epoch 75/100
# 20/20 [==============================] - 2s 108ms/step - loss: 0.0029
# Epoch 76/100
# 20/20 [==============================] - 2s 112ms/step - loss: 0.0029
# Epoch 77/100
# 20/20 [==============================] - 2s 111ms/step - loss: 0.0025
# Epoch 78/100
# 20/20 [==============================] - 2s 112ms/step - loss: 0.0025
# Epoch 79/100
# 20/20 [==============================] - 2s 111ms/step - loss: 0.0024
# Epoch 80/100
# 20/20 [==============================] - 2s 111ms/step - loss: 0.0024
# Epoch 81/100
# 20/20 [==============================] - 2s 111ms/step - loss: 0.0021
# Epoch 82/100
# 20/20 [==============================] - 2s 108ms/step - loss: 0.0024
# Epoch 83/100
# 20/20 [==============================] - 2s 113ms/step - loss: 0.0024
# Epoch 84/100
# 20/20 [==============================] - 2s 123ms/step - loss: 0.0023
# Epoch 85/100
# 20/20 [==============================] - 2s 120ms/step - loss: 0.0026
# Epoch 86/100
# 20/20 [==============================] - 2s 119ms/step - loss: 0.0022
# Epoch 87/100
# 20/20 [==============================] - 2s 117ms/step - loss: 0.0024
# Epoch 88/100
# 20/20 [==============================] - 2s 119ms/step - loss: 0.0023
# Epoch 89/100
# 20/20 [==============================] - 2s 113ms/step - loss: 0.0022
# Epoch 90/100
# 20/20 [==============================] - 2s 118ms/step - loss: 0.0023
# Epoch 91/100
# 20/20 [==============================] - 2s 114ms/step - loss: 0.0027
# Epoch 92/100
# 20/20 [==============================] - 2s 114ms/step - loss: 0.0025
# Epoch 93/100
# 20/20 [==============================] - 2s 118ms/step - loss: 0.0021
# Epoch 94/100
# 20/20 [==============================] - 2s 119ms/step - loss: 0.0023
# Epoch 95/100
# 20/20 [==============================] - 2s 121ms/step - loss: 0.0021
# Epoch 96/100
# 20/20 [==============================] - 2s 116ms/step - loss: 0.0020
# Epoch 97/100
# 20/20 [==============================] - 2s 122ms/step - loss: 0.0021
# Epoch 98/100
# 20/20 [==============================] - 2s 111ms/step - loss: 0.0022
# Epoch 99/100
# 20/20 [==============================] - 2s 115ms/step - loss: 0.0023
# Epoch 100/100
# 20/20 [==============================] - 2s 111ms/step - loss: 0.0021

# %% [markdown]
# ## Step-4 Preparing test data

# %%
ds_test = pd.read_csv("Google_Stock_Price_Train.csv")
actual_stock_price = ds_test.iloc[:500,1:2].values
ds_test
# Out:
#             Date    Open    High     Low   Close      Volume
# 0       1/3/2012  325.25  332.83  324.97  663.59   7,380,500
# 1       1/4/2012  331.27  333.87  329.08  666.45   5,749,400
# 2       1/5/2012  329.83  330.75  326.89  657.21   6,590,300
# 3       1/6/2012  328.34  328.77  323.68  648.24   5,405,900
# 4       1/9/2012  322.04  322.29  309.46  620.76  11,688,800
# ...          ...     ...     ...     ...     ...         ...
# 1253  12/23/2016  790.90  792.74  787.28  789.91     623,400
# 1254  12/27/2016  790.68  797.86  787.66  791.55     789,100
# 1255  12/28/2016  793.70  794.23  783.20  785.05   1,153,800
# 1256  12/29/2016  783.33  785.93  778.92  782.79     744,300
# 1257  12/30/2016  782.75  782.78  770.41  771.82   1,770,000
#
# [1258 rows x 6 columns]

# %%
dataset_total = pd.concat((ds_train['Open'],ds_test['Open']),axis=0)
inputs = dataset_total[len(dataset_total)-len(ds_test)-30:].values

inputs = inputs.reshape(-1,1)
inputs = MMscaler.transform(inputs)

x_test = []
for i in range(30,500):
    x_test.append(inputs[i-30:i,0])
x_test = np.array(x_test)
x_test = np.reshape(x_test,(x_test.shape[0],x_test.shape[1],1))
# Out:
# C:\Users\chatt\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(

# %%
pred_stock_price = regressor.predict(x_test)
pred_stock_price = MMscaler.inverse_transform(pred_stock_price)
# Out:
# 15/15 [==============================] - 3s 29ms/step

# %% [markdown]
# ## Step-5 Visualizing the data (Actual Value vs Predicted Value)

# %%
plt.plot(actual_stock_price,color='red',label='Actual Stock Price')
plt.plot(pred_stock_price,color='blue',label='Predicted Stock Price')
plt.title('Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.show()
